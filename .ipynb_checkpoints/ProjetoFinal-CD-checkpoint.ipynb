# %% [markdown]
# # PROJETO DE CIÊNCIA DE DADOS
#
# #### PROFESSOR:
#
# IVANOVITCH MEDEIROS DANTAS DA SILVA
#
# #### GRUPO:
#
# AILSON FORTE DOS SANTOS
#
# ALLAN VALDIVINO GONÇALVES
#
# CINTHIA KATIANE ARAÚJO DO NASCIMENTO
#
# WELLIGTON MIGUEL DA SILVA
#
# _______________________________________________________________

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1a ETAPA: FIRST THINGS FIRST
#
#
# #### TAREFAS:
#
# * Coleta
# * Limpeza
#
# ### 1.1 Informações dos Curriculos e Componentes
#
# #### DATASETS UTILIZADOS
#
# Componentes:
#
# http://dados.ufrn.br/dataset/3fea67e8-6916-4ed0-aaa6-9a8ca06a9bdc/resource/9a3521d2-4bc5-4fda-93f0-f701c8a20727/download/componentes-curriculares-presenciais.csv
#
# Curriculos:
#
# http://dados.ufrn.br/dataset/82aca3f1-f7ee-425e-bf1e-b6a1d6811bf4/resource/3f25d054-c5d2-4bf2-8cd4-8e0a2e4f63ce/download/curriculo-componente-graduacao.csv
#
# ### CÓDIGO

# %%
df_componentes = pd.read_csv('dados/componentes-curriculares-presenciais.csv',
                            error_bad_lines=False, sep=';', low_memory=False,
                            usecols=['id_componente','tipo_componente', 'codigo', 'nivel', 'nome', 'ch_total', 'equivalencia', 'pre_requisito','co_requisito'])
df_componentes.head()
# Out:
#   id_componente tipo_componente  codigo nivel  \
# 0         18643      DISCIPLINA  MUT508     T
# 1         18644      DISCIPLINA  MUT516     T
# 2         18645      DISCIPLINA  MUT520     T
# 3         18646      DISCIPLINA  MUT165     T
# 4         18647      DISCIPLINA  MUT167     T
#
#                                nome ch_total equivalencia pre_requisito  \
# 0  COMPOSIÇÃO EM MÚSICA POPULAR III       60          NaN           NaN
# 1                      CO-REPETIÇÃO       30          NaN           NaN
# 2            CONTRABAIXO ACÚSTICO I       30          NaN           NaN
# 3              PIANO COMPLEMENTAR I       15          NaN           NaN
# 4            PIANO COMPLEMENTAR III       15          NaN           NaN
#
#   co_requisito
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df_componentes_imd = df_componentes[df_componentes.codigo.str.contains('IMD', na=False)]
df_componentes_imd.head()
# Out:
#       id_componente tipo_componente   codigo nivel  \
# 20970         51954          MODULO  IMD0001     L
# 21229         52247          MODULO  IMD0002     L
# 21230         52248          MODULO  IMD0003     L
# 21231         52249          MODULO  IMD0004     L
# 21371         52390          MODULO  IMD0005     L
#
#                                    nome ch_total equivalencia pre_requisito  \
# 20970              INOVAÇÃO TECNOLÓGICA       15          NaN           NaN
# 21229              INOVAÇÃO TECNOLÓGICA       30          NaN           NaN
# 21230  PROCESSO E QUALIDADE DE SOFTWARE       30          NaN           NaN
# 21231              GERÊNCIA DE PROJETOS       30          NaN           NaN
# 21371              INOVAÇÃO TECNOLÓGICA       15          NaN           NaN
#
#       co_requisito
# 20970          NaN
# 21229          NaN
# 21230          NaN
# 21231          NaN
# 21371          NaN

# %%
df_curriculo = pd.read_csv('dados/curriculo-componente-graduacao.csv',
                            error_bad_lines=False, sep=';')
df_curriculo.head()
# Out:
#    id_curriculo_componente  id_curriculo  id_componente_curricular  \
# 0                   129366        100579                     23161
# 1                   121276        100302                     25440
# 2                 19001074      18999000                     25603
# 3                116106239     107405556                     41803
# 4                   127478        100200                     22865
#
#    semestre_oferta tipo_vinculo_componente nivel_ensino
# 0                8                OPTATIVO    GRADUAÇÃO
# 1                5                OPTATIVO    GRADUAÇÃO
# 2                1             OBRIGATÓRIO    GRADUAÇÃO
# 3                0                OPTATIVO    GRADUAÇÃO
# 4                6                OPTATIVO    GRADUAÇÃO

# %%
df_curriculo.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)

# %%
df_componentes_imd.id_componente = df_componentes_imd.id_componente.astype(np.int64)
df_curriculo.id_componente = df_curriculo.id_componente.astype(np.int64)
# Out:
# C:\Users\Cinthia\Anaconda3\lib\site-packages\pandas\core\generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_curriculo_componente = pd.merge(df_curriculo, df_componentes_imd, on='id_componente')
df_curriculo_componente = df_curriculo_componente.drop(['nivel', 'tipo_componente'], axis=1)
df_curriculo_componente.head()
# Out:
#    id_curriculo_componente  id_curriculo  id_componente  semestre_oferta  \
# 0                 96348490      96335318          52682                6
# 1                105757383     105755388          52682                0
# 2                 96338889      96338399          52682                5
# 3                101667945     101658777          52682                0
# 4                101668653     101668583          52682                0
#
#   tipo_vinculo_componente nivel_ensino   codigo  \
# 0                OPTATIVO    GRADUAÇÃO  IMD0406
# 1                OPTATIVO    GRADUAÇÃO  IMD0406
# 2             OBRIGATÓRIO    GRADUAÇÃO  IMD0406
# 3                OPTATIVO    GRADUAÇÃO  IMD0406
# 4                OPTATIVO    GRADUAÇÃO  IMD0406
#
#                                nome ch_total equivalencia pre_requisito  \
# 0  PROTOCOLO E SERVIÇOS DE INTERNET       30          NaN  ( IMD0043 )
# 1  PROTOCOLO E SERVIÇOS DE INTERNET       30          NaN  ( IMD0043 )
# 2  PROTOCOLO E SERVIÇOS DE INTERNET       30          NaN  ( IMD0043 )
# 3  PROTOCOLO E SERVIÇOS DE INTERNET       30          NaN  ( IMD0043 )
# 4  PROTOCOLO E SERVIÇOS DE INTERNET       30          NaN  ( IMD0043 )
#
#   co_requisito
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# _____

# %% [markdown]
# ### 1.2 Informações dos discentes
#
# #### DATASETS UTILIZADOS
#
# Turmas (2015 - 2017):
#
# http://dados.ufrn.br/dataset/turmas
#
# Matriculas (2015 - 2017):
#
# http://dados.ufrn.br/dataset/matriculas-componentes
#
# Informações Complementares dos Discentes:
#
# http://dados.ufrn.br/dataset/80b1a8e9-2e40-4c6c-97ea-d595a3c8b8f5/resource/0e287fe5-badb-4b34-b1bf-8815db5dfbeb/download/dados-pessoais-discentes
#
# ### CÓDIGO

# %%
turma_periodo = ['dados/turmas-2015.1.csv','dados/turmas-2015.2.csv',
                 'dados/turmas-2016.1.csv','dados/turmas-2016.2.csv', 
                 'dados/turmas-2017.1.csv','dados/turmas-2017.2.csv',]

colunas = ['id_turma', 'codigo_turma','id_componente_curricular', 'ano','periodo', 'nivel_ensino', 'periodo','situacao_turma']

# %%
frames_turmas = [pd.read_csv(periodo, sep=';', usecols=colunas) for periodo in turma_periodo]

# %%
df_turmas = pd.concat(frames_turmas)

# %%
df_turmas_consolidadas = df_turmas[df_turmas.situacao_turma == 'CONSOLIDADA']
df_turmas_consolidadas.head()
# Out:
#    id_turma codigo_turma  id_componente_curricular nivel_ensino   ano  \
# 0   1217099           01                     52922   LATO SENSU  2015
# 1   1217100           01                     52921   LATO SENSU  2015
# 2   1217101           01                     52925   LATO SENSU  2015
# 3   1217102           01                     52920   LATO SENSU  2015
# 4   1217102           01                     52920   LATO SENSU  2015
#
#    periodo situacao_turma
# 0        1    CONSOLIDADA
# 1        1    CONSOLIDADA
# 2        1    CONSOLIDADA
# 3        1    CONSOLIDADA
# 4        1    CONSOLIDADA

# %%
df_turmas_consolidadas.id_componente_curricular = df_turmas_consolidadas.id_componente_curricular.astype(np.int64)
# Out:
# C:\Users\Cinthia\Anaconda3\lib\site-packages\pandas\core\generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
#curriculo_comum = df_curriculo_comum.id_componente.unique()
#print (curriculo_comum)

# %%
#df_comum = df_turmas_consolidadas.loc[df_turmas_consolidadas['id_componente_curricular'].isin(curriculo_comum)]
#df_comum.head()

# %%
matriculas_periodo = ['dados/matricula-2015.1.csv','dados/matricula-2015.2.csv',
                      'dados/matricula-2016.1.csv','dados/matricula-2016.2.csv',
                      'dados/matricula-2017.1.csv','dados/matricula-2017.2.csv',]

colunas_mat = ['descricao','discente','faltas_unidade','id_curso','id_turma','media_final','nota','numero_total_faltas','reposicao','unidade']

# %%
frames_mat = [pd.read_csv(matric, sep=';')[colunas_mat] for matric in matriculas_periodo]

# %%
df_matriculas = pd.concat(frames_mat, sort=True)

# %%
df_matriculas.head()
# Out:
#    descricao                          discente  faltas_unidade     id_curso  \
# 0  REPROVADO  8833c0e056f90497742882bfcc81b685             0.0  100300443.0
# 1  REPROVADO  8833c0e056f90497742882bfcc81b685             0.0  100300443.0
# 2   APROVADO  7a0a661326418111f7d17aab098757aa             0.0  100300443.0
# 3   APROVADO  7a0a661326418111f7d17aab098757aa             0.0  100300443.0
# 4   APROVADO  7a0a661326418111f7d17aab098757aa             0.0  100300443.0
#
#    id_turma  media_final  nota  numero_total_faltas reposicao  unidade
# 0  57562481          0.0   0.0                  0.0         f      2.0
# 1  57562481          0.0   0.0                  0.0         f      3.0
# 2  57562481          8.9   8.9                  0.0         f      1.0
# 3  57562481          8.9   8.9                  0.0         f      2.0
# 4  57562481          8.9   8.9                  0.0         f      3.0

# %%
df_turma_matricula = pd.merge(df_turmas_consolidadas, df_matriculas, on='id_turma')
df_turma_matricula.head()
# Out:
#    id_turma codigo_turma  id_componente_curricular nivel_ensino   ano  \
# 0   1217099           01                     52922   LATO SENSU  2015
# 1   1217099           01                     52922   LATO SENSU  2015
# 2   1217099           01                     52922   LATO SENSU  2015
# 3   1217099           01                     52922   LATO SENSU  2015
# 4   1217099           01                     52922   LATO SENSU  2015
#
#    periodo situacao_turma    descricao                          discente  \
# 0        1    CONSOLIDADA  DESISTENCIA  50b4ff86ad190e4ec463dba97ae745a8
# 1        1    CONSOLIDADA  DESISTENCIA  7f23d4bef06eb93381d3bd02494d1ee6
# 2        1    CONSOLIDADA  DESISTENCIA  444be6838e9d059cfe83ec0def0f7431
# 3        1    CONSOLIDADA     APROVADO  5fdb41574051227d9a77537dd13325b4
# 4        1    CONSOLIDADA     APROVADO  5fdb41574051227d9a77537dd13325b4
#
#    faltas_unidade    id_curso  media_final  nota  numero_total_faltas  \
# 0             NaN  95825620.0          NaN   NaN                  NaN
# 1             NaN  95825620.0          NaN   NaN                  NaN
# 2             NaN  95825620.0          NaN   NaN                  NaN
# 3             0.0  95825620.0          8.0   8.0                  3.0
# 4             0.0  95825620.0          8.0   8.0                  3.0
#
#   reposicao  unidade
# 0       NaN      NaN
# 1       NaN      NaN
# 2       NaN      NaN
# 3         f      1.0
# 4         f      2.0

# %%
colunas_remover = ['codigo_turma', 'nivel_ensino', 'situacao_turma']
df_turma_matricula = df_turma_matricula.drop(colunas_remover, axis=1)

# %%
df_turma_matricula.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)

df_turma_matricula.head()
# Out:
#    id_turma  id_componente   ano  periodo    descricao  \
# 0   1217099          52922  2015        1  DESISTENCIA
# 1   1217099          52922  2015        1  DESISTENCIA
# 2   1217099          52922  2015        1  DESISTENCIA
# 3   1217099          52922  2015        1     APROVADO
# 4   1217099          52922  2015        1     APROVADO
#
#                            discente  faltas_unidade    id_curso  media_final  \
# 0  50b4ff86ad190e4ec463dba97ae745a8             NaN  95825620.0          NaN
# 1  7f23d4bef06eb93381d3bd02494d1ee6             NaN  95825620.0          NaN
# 2  444be6838e9d059cfe83ec0def0f7431             NaN  95825620.0          NaN
# 3  5fdb41574051227d9a77537dd13325b4             0.0  95825620.0          8.0
# 4  5fdb41574051227d9a77537dd13325b4             0.0  95825620.0          8.0
#
#    nota  numero_total_faltas reposicao  unidade
# 0   NaN                  NaN       NaN      NaN
# 1   NaN                  NaN       NaN      NaN
# 2   NaN                  NaN       NaN      NaN
# 3   8.0                  3.0         f      1.0
# 4   8.0                  3.0         f      2.0

# %%
df_tm = df_turma_matricula.loc[~df_turma_matricula['descricao'].isin(['INDEFERIDO', 'CANCELADO', 'EXCLUIDA', 'DESISTENCIA'])]
df_tm.sort_values('unidade').drop_duplicates(subset=['id_turma', 'discente'], keep='last')

df_tm.head()
# Out:
#    id_turma  id_componente   ano  periodo descricao  \
# 3   1217099          52922  2015        1  APROVADO
# 4   1217099          52922  2015        1  APROVADO
# 5   1217099          52922  2015        1  APROVADO
# 6   1217099          52922  2015        1  APROVADO
# 7   1217099          52922  2015        1  APROVADO
#
#                            discente  faltas_unidade    id_curso  media_final  \
# 3  5fdb41574051227d9a77537dd13325b4             0.0  95825620.0          8.0
# 4  5fdb41574051227d9a77537dd13325b4             0.0  95825620.0          8.0
# 5  5fdb41574051227d9a77537dd13325b4             0.0  95825620.0          8.0
# 6  bd49325f27c692cf3503c55fc0e89c4d             0.0  95825620.0          9.0
# 7  bd49325f27c692cf3503c55fc0e89c4d             0.0  95825620.0          9.0
#
#    nota  numero_total_faltas reposicao  unidade
# 3   8.0                  3.0         f      1.0
# 4   8.0                  3.0         f      2.0
# 5   8.0                  3.0         f      3.0
# 6   9.0                  0.0         f      1.0
# 7   9.0                  0.0         f      2.0

# %%
df_info_complementar = pd.read_csv('http://dados.ufrn.br/dataset/80b1a8e9-2e40-4c6c-97ea-d595a3c8b8f5/resource/0e287fe5-badb-4b34-b1bf-8815db5dfbeb/download/dados-pessoais-discentes',
sep=';')
df_info_complementar.rename(columns={'id_discente': 'discente'}, inplace=True)

df_info_complementar.head()
# Out:
#                            discente sexo data_nascimento           raca  \
# 0  0e356f33d9f25c70bd7b98ef1bd1ecd4    M      03-10-1943  Não Informado
# 1  a3f7753971d7ca9c1648616b1f7e4c48    M      21-02-1949  Não Informado
# 2  d29e0a56e3cc973750e2d2cbabedc449    F      09-09-1947  Não Informado
# 3  d4f89fe5c6dd43692b3c1fc4ce324fd5    M      22-04-1949  Não Informado
# 4  e2f244371122aea4140427ada6f391b4    M      21-03-1944  Não Informado
#
#          estado_origem cidade_origem               estado municipio    bairro  \
# 0  Rio Grande do Norte         NATAL  Rio Grande do Norte     NATAL  NEOPOLIS
# 1       Rio de Janeiro           NaN                  NaN       NaN       NaN
# 2                  NaN           NaN                  NaN       NaN       NaN
# 3  Rio Grande do Norte           NaN                  NaN       NaN       NaN
# 4  Rio Grande do Norte         NATAL  Rio Grande do Norte     NATAL   ALECRIM
#
#   nivel_ensino forma_ingresso  ano_ingresso  periodo_ingresso cotista
# 0    GRADUAÇÃO     VESTIBULAR          1969               1.0       f
# 1    GRADUAÇÃO     VESTIBULAR          1970               1.0       f
# 2    GRADUAÇÃO     VESTIBULAR          1970               1.0       f
# 3    GRADUAÇÃO     VESTIBULAR          1970               1.0       f
# 4    GRADUAÇÃO     VESTIBULAR          1970               1.0       f

# %%
df_info = pd.merge(df_tm, df_info_complementar, on='discente')
df_info = df_info.drop(['nivel_ensino','ano_ingresso', 'periodo_ingresso'], axis=1)
df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8873318 entries, 0 to 8873317
# Data columns (total 23 columns):
# id_turma               int64
# id_componente          int64
# ano                    int64
# periodo                int64
# descricao              object
# discente               object
# faltas_unidade         float64
# id_curso               float64
# media_final            float64
# nota                   float64
# numero_total_faltas    float64
# reposicao              object
# unidade                float64
# sexo                   object
# data_nascimento        object
# raca                   object
# estado_origem          object
# cidade_origem          object
# estado                 object
# municipio              object
# bairro                 object
# forma_ingresso         object
# cotista                object
# dtypes: float64(6), int64(4), object(13)
# memory usage: 1.6+ GB

# %%
df_geral = pd.merge(df_info, df_curriculo_componente, on='id_componente')
df_geral.head()
# Out:
#    id_turma  id_componente   ano  periodo          descricao  \
# 0   1239374          55031  2015        1  APROVADO POR NOTA
# 1   1239374          55031  2015        1  APROVADO POR NOTA
# 2   1239374          55031  2015        1  APROVADO POR NOTA
# 3   1239374          55031  2015        1  APROVADO POR NOTA
# 4   1239374          55031  2015        1  APROVADO POR NOTA
#
#                            discente  faltas_unidade    id_curso  media_final  \
# 0  a8e2e545c4b9385773d1fd98188f6f59             0.0  92127264.0          6.9
# 1  a8e2e545c4b9385773d1fd98188f6f59             0.0  92127264.0          6.9
# 2  a8e2e545c4b9385773d1fd98188f6f59             0.0  92127264.0          6.9
# 3  a8e2e545c4b9385773d1fd98188f6f59             0.0  92127264.0          6.9
# 4  a8e2e545c4b9385773d1fd98188f6f59             0.0  92127264.0          6.9
#
#    nota     ...       id_curriculo semestre_oferta  tipo_vinculo_componente  \
# 0   6.9     ...          101669220               1              OBRIGATÓRIO
# 1   6.9     ...          101668583               1              OBRIGATÓRIO
# 2   6.9     ...          102359682               1              OBRIGATÓRIO
# 3   6.9     ...          102200805               1              OBRIGATÓRIO
# 4   6.9     ...          105694093               1              OBRIGATÓRIO
#
#   nivel_ensino   codigo                                        nome ch_total  \
# 0    GRADUAÇÃO  IMD0019  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI      180
# 1    GRADUAÇÃO  IMD0019  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI      180
# 2    GRADUAÇÃO  IMD0019  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI      180
# 3    GRADUAÇÃO  IMD0019  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI      180
# 4    GRADUAÇÃO  IMD0019  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI      180
#
#                                         equivalencia pre_requisito  \
# 0  ( IMD0014 ) OU ( ( IMD1001 E IMD1002 E IMD1003...           NaN
# 1  ( IMD0014 ) OU ( ( IMD1001 E IMD1002 E IMD1003...           NaN
# 2  ( IMD0014 ) OU ( ( IMD1001 E IMD1002 E IMD1003...           NaN
# 3  ( IMD0014 ) OU ( ( IMD1001 E IMD1002 E IMD1003...           NaN
# 4  ( IMD0014 ) OU ( ( IMD1001 E IMD1002 E IMD1003...           NaN
#
#   co_requisito
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 34 columns]

# %%
colunas = ['nota','nivel_ensino', 'forma_ingresso', 'faltas_unidade','numero_total_faltas','reposicao','unidade']
df_geral = df_geral.drop(colunas, axis=1)
df_geral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 454033 entries, 0 to 454032
# Data columns (total 27 columns):
# id_turma                   454033 non-null int64
# id_componente              454033 non-null int64
# ano                        454033 non-null int64
# periodo                    454033 non-null int64
# descricao                  454033 non-null object
# discente                   454033 non-null object
# id_curso                   453091 non-null float64
# media_final                439207 non-null float64
# sexo                       454033 non-null object
# data_nascimento            454033 non-null object
# raca                       454033 non-null object
# estado_origem              453053 non-null object
# cidade_origem              453573 non-null object
# estado                     448159 non-null object
# municipio                  448159 non-null object
# bairro                     404920 non-null object
# cotista                    454033 non-null object
# id_curriculo_componente    454033 non-null int64
# id_curriculo               454033 non-null int64
# semestre_oferta            454033 non-null int64
# tipo_vinculo_componente    454033 non-null object
# codigo                     454033 non-null object
# nome                       454033 non-null object
# ch_total                   454033 non-null object
# equivalencia               342178 non-null object
# pre_requisito              241961 non-null object
# co_requisito               62112 non-null object
# dtypes: float64(2), int64(7), object(18)
# memory usage: 97.0+ MB

# %% [markdown]
# ___________
#
# ##### ANÁLISE

# %%
df_geral.cotista.value_counts()
# Out:
# f    279741
# t    174292
# Name: cotista, dtype: int64

# %%
df_geral.descricao.value_counts()
# Out:
# APROVADO POR NOTA                   156663
# APROVADO                            127569
# REPROVADO                            87620
# REPROVADO POR MÉDIA E POR FALTAS     65960
# TRANCADO                             14886
# REPROVADO POR NOTA                     846
# REPROVADO POR FALTAS                   357
# REPROVADO POR NOTA E FALTA             132
# Name: descricao, dtype: int64

# %%
cotistas = df_geral[df_geral.cotista == 't']
n_cotista = df_geral[df_geral.cotista == 'f']

# %%
cotistas.descricao.value_counts()
# Out:
# APROVADO POR NOTA                   63554
# APROVADO                            43822
# REPROVADO                           34893
# REPROVADO POR MÉDIA E POR FALTAS    26513
# TRANCADO                             4949
# REPROVADO POR NOTA                    378
# REPROVADO POR FALTAS                  108
# REPROVADO POR NOTA E FALTA             75
# Name: descricao, dtype: int64

# %%
n_cotista.descricao.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-ba499673592a> in <module>()
# ----> 1 n_cotistas.descricao.value_counts()
#
# NameError: name 'n_cotistas' is not defined

# %% [markdown]
# ____

# %% [markdown]
# ## A ideia é plotar a estrutura curricular do BTI no formato de grafo

# %%
import networkx as nx
import matplotlib.pyplot as plt
import math

# %%
df_grade = df_curriculo_comum
df_grade.pre_requisito = df_grade.pre_requisito.str.replace('(', '')
df_grade.pre_requisito = df_grade.pre_requisito.str.replace(')', '')
df_grade.pre_requisito = df_grade.pre_requisito.str.replace(' ', '')

df_grade
# Out:
#       id_curriculo_componente  id_componente  semestre_oferta   codigo  \
# 3                   101667945          52682                0  IMD0406
# 26                  101659808          52665                2  IMD0034
# 36                  115630315          61099                0  IMD0244
# 45                  101667703          55049                0  IMD0335
# 53                  112438354          55047                0  IMD0333
# 65                  101667744          55038                0  IMD0321
# 75                  101667719          55059                0  IMD0521
# 76                  101667709          52690                0  IMD0502
# 92                  101667785          55074                0  IMD0422
# 102                 101659833          55022                2  IMD0028
# 112                 101659835          52664                3  IMD0033
# 131                 101667702          55045                0  IMD0331
# 133                 101667947          52672                0  IMD0308
# 148                 115630304          61116                0  IMD0270
# 154                 101667950          52796                0  IMD0414
# 170                 101667701          55043                0  IMD0328
# 173                 115630313          61097                0  IMD0242
# 181                 115630308          61120                0  IMD0274
# 190                 121664707          63932                0  IMD0707
# 195                 125078416          55062                0  IMD0603
# 213                 121664709          63937                0  IMD0709
# 222                 101667696          52536                0  IMD0011
# 232                 115627951          61132                0  IMD0822
# 240                 101667778          52686                0  IMD0415
# 248                 121664711          63935                0  IMD0110
# 255                 101667934          55085                0  IMD0524
# 264                 115630310          61122                0  IMD0276
# 268                 101667716          52702                0  IMD0515
# 280                 101659837          55027                4  IMD0040
# 296                 111304723          59732                0  IMD0102
# ...                       ...            ...              ...      ...
# 1139                101659810          55023                3  IMD0029
# 1150                101659802          55082                1  IMD0020
# 1159                101667994          55051                0  IMD0337
# 1166                101667704          55050                0  IMD0336
# 1178                115630295          61114                0  IMD0265
# 1188                101667948          52791                0  IMD0409
# 1196                101667718          55055                0  IMD0517
# 1205                101667715          52700                0  IMD0513
# 1210                101667782          55044                0  IMD0326
# 1217                115630305          61117                0  IMD0271
# 1227                115630293          61112                0  IMD0263
# 1243                101667941          55046                0  IMD0332
# 1249                101659836          55026                4  IMD0039
# 1269                115630303          61094                0  IMD0256
# 1275                101667936          52788                0  IMD0412
# 1296                101667712          52697                0  IMD0510
# 1297                101667708          55083                0  IMD0423
# 1308                115630297          61083                0  IMD0250
# 1323                115630320          61104                0  IMD0232
# 1336                101667786          55039                0  IMD0322
# 1352                111304728          59737                0  IMD0107
# 1359                115630291          61110                0  IMD0261
# 1365                115630318          61102                0  IMD0230
# 1375                121664710          63934                0  IMD0725
# 1382                115630321          61105                0  IMD0233
# 1389                118878573          62886                0  IMD0702
# 1402                111304724          59733                0  IMD0103
# 1416                112438357          55096                0  IMD0329
# 1424                115630300          61086                0  IMD0253
# 1434                128117222          66482                0  IMD0605
#
#                                                    nome ch_total  \
# 3                      PROTOCOLO E SERVIÇOS DE INTERNET       30
# 26                        VETORES E GEOMETRIA ANALÍTICA       60
# 36    TÓPICOS ESPECIAIS EM SISTEMAS DE INFORMAÇÃO DE...       60
# 45                                  TÓPICOS ESPECIAIS I       60
# 53    PROJETO DE SOFTWARE E TESTES EM SISTEMAS EMBAR...       60
# 65              PROJETOS BASEADOS EM MICROCONTROLADORES       60
# 75                        FUNDAMENTOS DE JOGOS DIGITAIS       60
# 76    PROCESSO DE DESENVOLVIMENTO DE SOFTWARE EDUCAC...       60
# 92                 SISTEMAS DE INTELIGÊNCIA EMPRESARIAL       60
# 102             FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I       90
# 112                                       PROBABILIDADE       60
# 131           DESENVOLVIMENTO EM PLATAFORMAS EMBARCADAS       60
# 133                   SISTEMAS EMBARCADOS DE TEMPO REAL       60
# 148       TÓPICOS ESPECIAIS EM REDES DE COMPUTADORES A"       60
# 154                   SISTEMA DE INFORMAÇÃO DISTRIBUÍDO       60
# 170   TÉCNICAS DE PROTOTIPAÇÃO E MONTAGEM DE CIRCUIT...       60
# 173   TÓPICOS ESPECIAIS EM SISTEMAS DE INFORMAÇÃO DE...       60
# 181       TÓPICOS ESPECIAIS EM REDES DE COMPUTADORES E"       60
# 190                 TECNOLOGIAS DE COMUNICAÇÃO DE DADOS       60
# 195                       TECNOLOGIAS EM LARGA ESCALA I       60
# 213                       PROJETO INTEGRADOR DE REDES I       60
# 222                                   CIRCUITOS LÓGICOS       90
# 232                     PROJETO DE INOVAÇÃO TECNOLÓGICA       60
# 240                      GESTÃO DE INFRAESTRUTURA DE TI       60
# 248    TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO XI       60
# 255                                EDUCAÇÃO A DISTÂNCIA       60
# 264       TÓPICOS ESPECIAIS EM REDES DE COMPUTADORES G"       60
# 268      TÓPICOS ESPECIAIS EM INFORMÁTICA EDUCACIONAL I       60
# 280                         LINGUAGEM DE PROGRAMAÇÃO II       60
# 296   TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO III       60
# ...                                                 ...      ...
# 1139                       ESTRUTURA DE DADOS BÁSICAS I       60
# 1150               TECNOLOGIA DA INFORMAÇÃO E SOCIEDADE       30
# 1159                                           TI VERDE       60
# 1166                               TÓPICOS ESPECIAIS II       60
# 1178             TÓPICOS ESPECIAIS EM BIOINFORMÁTICA F"       60
# 1188                 DESENVOLVIMENTO DE SISTEMAS WEB II       60
# 1196  FUNDAMENTOS PEDAGÓGICOS PARA A INFORMÁTICA EDU...       60
# 1205                                   EMPREENDEDORISMO       60
# 1210                    PROCESSAMENTO DIGITAL DE SINAIS       60
# 1217      TÓPICOS ESPECIAIS EM REDES DE COMPUTADORES B"       60
# 1227             TÓPICOS ESPECIAIS EM BIOINFORMÁTICA D"       60
# 1243             ARQUITETURAS AVANÇADAS DE COMPUTADORES       60
# 1249                     ESTRUTURAS DE DADOS BÁSICAS II       60
# 1269    TÓPICOS ESPECIAIS EM INFORMÁTICA EDUCACIONAL G"       60
# 1275                    INTRODUÇÃO AO TESTE DE SOFTWARE       60
# 1296                             ACESSIBILIDADE DIGITAL       60
# 1297                               DESIGN DE SOFTWARE I       90
# 1308    TÓPICOS ESPECIAIS EM INFORMÁTICA EDUCACIONAL A"       60
# 1323        TÓPICOS ESPECIAIS EM SISTEMAS EMBARCADOS C"       60
# 1336                  SISTEMAS DIGITAIS RECONFIGURÁVEIS       90
# 1352  TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO ...       60
# 1359             TÓPICOS ESPECIAIS EM BIOINFORMÁTICA B"       60
# 1365        TÓPICOS ESPECIAIS EM SISTEMAS EMBARCADOS A"       60
# 1375  DESENVOLVIMENTO DE PROJETOS DE REDES DE COMPUT...       60
# 1382        TÓPICOS ESPECIAIS EM SISTEMAS EMBARCADOS D"       60
# 1389                      SERVIÇOS DE REDE E TRANSPORTE       60
# 1402   TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO IV       60
# 1416                              PROJETO INTEGRADO III       90
# 1424    TÓPICOS ESPECIAIS EM INFORMÁTICA EDUCACIONAL D"       60
# 1434                       SEMINÁRIOS EM BIOINFORMÁTICA       30
#
#                                            equivalencia  \
# 3                                                   NaN
# 26                ( ECT1112 E ECT1211 ) OU ( ECT2102 )
# 36                                                  NaN
# 45                                                  NaN
# 53                                                  NaN
# 65                                         ( DCA0444 )
# 75                                                  NaN
# 76                                         ( DIM0510 )
# 92                                                  NaN
# 102                  ( IMD0013 OU DIM0400 OU DIM0115 )
# 112                                                 NaN
# 131                                                 NaN
# 133                                                 NaN
# 148                                                 NaN
# 154                                                 NaN
# 170                                                 NaN
# 173                                                 NaN
# 181                                                 NaN
# 190                                                 NaN
# 195                                                 NaN
# 213                                                 NaN
# 222   ( DIM0109 ) OU ( DIM0402 E DIM0403 ) OU ( DCA0...
# 232                                                 NaN
# 240                                                 NaN
# 248                                                 NaN
# 255                                        ( IMD0508 )
# 264                                                 NaN
# 268                                                 NaN
# 280          ( DIM0111 ) OU ( IMD0035 ) OU ( DIM0116 )
# 296                                                 NaN
# ...                                                 ...
# 1139         ( DIM0110 ) OU ( IMD0022 ) OU ( DIM0119 )
# 1150                        ( IMD0015 ) OU ( ECT2106 )
# 1159                                                NaN
# 1166                                                NaN
# 1178                                                NaN
# 1188                                       ( DIM0547 )
# 1196                                       ( IMD0501 )
# 1205                                           DIM0345
# 1210                            ( DCA0453 OU DCA0423 )
# 1217                                                NaN
# 1227                                                NaN
# 1243                                                NaN
# 1249         ( DIM0111 ) OU ( IMD0032 ) OU ( DIM0117 )
# 1269                                                NaN
# 1275                                           DIM0507
# 1296                                                NaN
# 1297              ( IMD0503 E IMD0505 ) OU ( IMD0402 )
# 1308                                                NaN
# 1323                                                NaN
# 1336                                       ( DCA0119 )
# 1352                                                NaN
# 1359                                                NaN
# 1365                                                NaN
# 1375                                                NaN
# 1382                                                NaN
# 1389                                                NaN
# 1402                                                NaN
# 1416                                                NaN
# 1424                                                NaN
# 1434                                                NaN
#
#                           pre_requisito             co_requisito
# 3                               IMD0043                      NaN
# 26                              IMD0019                      NaN
# 36                                  NaN                      NaN
# 45                                  NaN                      NaN
# 53                              IMD0323                      NaN
# 65                              IMD0012  ( IMD0021 OU IMD0041 )
# 75                                  NaN                      NaN
# 76                                  NaN                      NaN
# 92                              IMD0405                      NaN
# 102                             IMD0019                      NaN
# 112                             IMD0024                      NaN
# 131                                 NaN                      NaN
# 133            IMD0036OUIMD0042EIMD0323                      NaN
# 148                                 NaN                      NaN
# 154                             IMD0410                      NaN
# 170                                 NaN                      NaN
# 173                                 NaN                      NaN
# 181                                 NaN                      NaN
# 190                             IMD0043                      NaN
# 195                             ICE1024                      NaN
# 213                                 NaN                      NaN
# 222                                 NaN             ( IMD0012 )
# 232                             IMD0040                      NaN
# 240                                 NaN                      NaN
# 248                                 NaN                      NaN
# 255                                 NaN                      NaN
# 264                                 NaN                      NaN
# 268                                 NaN                      NaN
# 280                             IMD0030             ( IMD0039 )
# 296                                 NaN                      NaN
# ...                                 ...                      ...
# 1139                            IMD0012             ( IMD0030 )
# 1150                                NaN                      NaN
# 1159                                NaN                      NaN
# 1166                                NaN                      NaN
# 1178                                NaN                      NaN
# 1188                                NaN             ( IMD0404 )
# 1196                                NaN                      NaN
# 1205                                NaN                      NaN
# 1210                    IMD0034EIMD0319                      NaN
# 1217                                NaN                      NaN
# 1227                                NaN                      NaN
# 1243                   IMD0021OUIMD0041                      NaN
# 1249                            IMD0029             ( IMD0040 )
# 1269                                NaN                      NaN
# 1275  IMD0035OUIMD0040EIMD0423OUIMD0503                      NaN
# 1296                                NaN                      NaN
# 1297                                NaN                      NaN
# 1308                                NaN                      NaN
# 1323                                NaN                      NaN
# 1336                            IMD0011                      NaN
# 1352                                NaN                      NaN
# 1359                                NaN                      NaN
# 1365                                NaN                      NaN
# 1375                                NaN                      NaN
# 1382                                NaN                      NaN
# 1389                                NaN                      NaN
# 1402                                NaN                      NaN
# 1416                            IMD0327   ( IMD0308 E IMD0328 )
# 1424                                NaN                      NaN
# 1434                                NaN                      NaN
#
# [147 rows x 9 columns]

# %%
de = []
para = []
links = {'from': de, 'to': para}
ids = []
groups = []
car = {'ID': ids, 'myvalue': groups}
pos = {}
ch = {1: [1,2,3,4], 2: [1,2,3,4,5], 3:[1,2,3,4], 4:[1,2]}

# %%
for _, row in df_grade.iterrows():
    ids.append(row.codigo)
    pos[row.codigo] = (row.semestre_oferta, ch[row.semestre_oferta].pop())

    if (str(row.pre_requisito).lower()!='nan'):
        de.append(row.pre_requisito)
        para.append(row.codigo)
        groups.append('group1')
    else:
        de.append(row.codigo)
        para.append(row.codigo)
        groups.append('group2')
        pass
    
# Build a dataframe with your connections
df = pd.DataFrame(links)
 
# And a data frame with characteristics for your nodes
carac = pd.DataFrame(car)
 
# Build your graph
G=nx.from_pandas_edgelist(df, 'from', 'to', edge_attr=True)
 
# The order of the node for networkX is the following order:
G.nodes()
# Thus, we cannot give directly the 'myvalue' column to netowrkX, we need to arrange the order!
 
# Here is the tricky part: I need to reorder carac to assign the good color to each node
carac= carac.set_index('ID')
carac=carac.reindex(G.nodes())
# And I need to transform my categorical column in a numerical value: group1->1, group2->2...
carac['myvalue']=pd.Categorical(carac['myvalue'])
carac['myvalue'].cat.codes

plt.rcParams['figure.figsize'] = (16,7)
# Custom the nodes:
nx.draw(G, pos, with_labels=True, node_color=carac['myvalue'].cat.codes, cmap=plt.cm.Set1, node_size=1500, edge_color='lightgrey', width=10.0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-804ada130e7a> in <module>()
#       1 for _, row in df_grade.iterrows():
#       2     ids.append(row.codigo)
# ----> 3     pos[row.codigo] = (row.semestre_oferta, ch[row.semestre_oferta].pop())
#       4
#       5     if (str(row.pre_requisito).lower()!='nan'):
#
# KeyError: 0

# %% [markdown]
# ____

# %% [markdown]
# # O passo final é atribuir peso aos nodes com base nas métricas
